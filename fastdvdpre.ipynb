# %% [markdown]
# <a href="https://colab.research.google.com/github/487-coder/VD_KD/blob/main/fastdvdpre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.kill(os.getpid(), 9)

# %%
# !pip install numpy==1.26.4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 113.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
! git clone https://github.com/487-coder/VD_KD.git
# Out:
# Cloning into 'VD_KD'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 19 (delta 0), reused 19 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 9.83 KiB | 9.83 MiB/s, done.

# %%
# !pip install torch==2.3.0 torchvision==0.18.0 \
    opencv-contrib-python==4.5.5.64 imageio==2.31.1 scikit-image==0.21.0 \
    tensorboard==2.15.2 numpy==1.26.4
#!pip uninstall opencv-python opencv-python-headless opencv-contrib-python
#!pip install opencv-contrib-python==4.5.5.64
# !pip install av==10.0.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.2/779.2 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 127.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 MB 36.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 124.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 124.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 115.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 96.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 55.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 20.0 MB/s eta 0:00:00
# ...

# %%
# !pip install gdown

# 下载 zip（把 FILE_ID 换成你的）
# !gdown --id 1VgNnnhKTP0ubfcYhlt_jsv7tI9AIX3B1 -O dataset.zip

# 解压
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1VgNnnhKTP0ubfcYhlt_jsv7tI9AIX3B1
# From (redirected): https://drive.google.com/uc?id=1VgNnnhKTP0ubfcYhlt_jsv7tI9AIX3B1&confirm=t&uuid=eb4e2968-59e0-448d-a846-6193e823ca65
# To: /content/dataset.zip
# 100% 307M/307M [00:07<00:00, 38.4MB/s]

# %%
# !unzip -q dataset.zip -d /content/VD_KD

# %%
# !gdown --id 12dfsrDQIW_pe6YOTHvfrP1NJ9ExpIkxD -O valset.zip
# !unzip -q valset.zip -d /content/VD_KD/val_data
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=12dfsrDQIW_pe6YOTHvfrP1NJ9ExpIkxD
# From (redirected): https://drive.google.com/uc?id=12dfsrDQIW_pe6YOTHvfrP1NJ9ExpIkxD&confirm=t&uuid=2f1ab45f-71b9-48ff-b9e9-80f297052126
# To: /content/valset.zip
# 100% 3.01G/3.01G [00:20<00:00, 147MB/s]

# %%
# !python /content/VD_KD/train.py \
    --server_data /content/VD_KD/480p \
    --batch_size 64 \
    --temp_patch_size 5 \
    --patch_size 96 \
    --max_number_patches 256000 \
    --pretrain_epoch 10 \
    --lr 0.001 \
    --noise_ival 0.0196078 0.215686 \
    --val_noiseL 0.0980392 \
    --val_data /content/VD_KD/val_data \
    --pretrain_model /content/check_point
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# cnm torch.Size([64, 5, 3, 96, 96])
# do_nothing new
# cnm torch.Size([64, 5, 3, 96, 96])
# rot90_flipud new
# cnm torch.Size([64, 5, 3, 96, 96])
# rot270 new
# cnm torch.Size([64, 5, 3, 96, 96])
# rot270 new
# Applied orthogonalization at epoch 5, step 2410
# cnm torch.Size([64, 5, 3, 96, 96])
# rot90 new
# cnm torch.Size([64, 5, 3, 96, 96])
# rot90 new
# cnm torch.Size([64, 5, 3, 96, 96])
# rot270 new
# cnm torch.Size([64, 5, 3, 96, 96])
# do_nothing new
# cnm torch.Size([64, 5, 3, 96, 96])
# rot270 new
# cnm torch.Size([64, 5, 3, 96, 96])
# rot180_flipud new
# cnm torch.Size([64, 5, 3, 96, 96])
# flipud new
# cnm torch.Size([64, 5, 3, 96, 96])
# add_noise new
# cnm torch.Size([64, 5, 3, 96, 96])
# do_nothing new
# cnm torch.Size([64, 5, 3, 96, 96])
# rot180_flipud new
# Applied orthogonalization at epoch 5, step 2420
# cnm torch.Size([64, 5, 3, 96, 96])
# rot90_flipud new
# cnm torch.Size([64, 5, 3, 96, 96])
# rot270 new
# ...
